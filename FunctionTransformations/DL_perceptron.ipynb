# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"C:\Users\YERSANSAI\OneDrive\Desktop\practise\college_student_placement_dataset.csv")
df.head(5)
# Out:
#   College_ID   IQ  Prev_Sem_Result  CGPA  Academic_Performance  \
# 0    CLG0030  107             6.61  6.28                     8
# 1    CLG0061   97             5.52  5.37                     8
# 2    CLG0036  109             5.36  5.83                     9
# 3    CLG0055  122             5.47  5.75                     6
# 4    CLG0004   96             7.91  7.69                     7
#
#   Internship_Experience  Extra_Curricular_Score  Communication_Skills  \
# 0                    No                       8                     8
# 1                    No                       7                     8
# 2                    No                       3                     1
# 3                   Yes                       1                     6
# 4                    No                       8                    10
#
#    Projects_Completed Placement
# 0                   4        No
# 1                   0        No
# 2                   1        No
# ...

# %%
df = df.drop(['College_ID'],axis = 1)

# %%
df.head()
# Out:
#     IQ  Prev_Sem_Result  CGPA  Academic_Performance Internship_Experience  \
# 0  107             6.61  6.28                     8                    No
# 1   97             5.52  5.37                     8                    No
# 2  109             5.36  5.83                     9                    No
# 3  122             5.47  5.75                     6                   Yes
# 4   96             7.91  7.69                     7                    No
#
#    Extra_Curricular_Score  Communication_Skills  Projects_Completed Placement
# 0                       8                     8                   4        No
# 1                       7                     8                   0        No
# 2                       3                     1                   1        No
# 3                       1                     6                   1        No
# 4                       8                    10                   2        No

# %%
x = df.drop(['Placement'],axis = 1)
y = df['Placement']

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder
scaler = StandardScaler()

# %%
x_scaled = scaler.fit_transform(x)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 x_scaled = scaler.fit_transform(x)
#
# File ~\OneDrive\Desktop\practise\.venv\Lib\site-packages\sklearn\utils\_set_output.py:319, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     317 @wraps(f)
#     318 def wrapped(self, X, *args, **kwargs):
# --> 319     data_to_wrap = f(self, X, *args, **kwargs)
#     320     if isinstance(data_to_wrap, tuple):
#     321         # only wrap the first output for cross decomposition
#     322         return_tuple = (
#     323             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     324             *data_to_wrap[1:],
#     325         )
#
# File ~\OneDrive\Desktop\practise\.venv\Lib\site-packages\sklearn\base.py:969, in TransformerMixin.fit_transform(self, X, y, **fit_params)
#     954         warnings.warn(
# ...

# %%
sns.scatterplot(x = df['cgpa'],y = df['placement_exam_marks'],hue = y)
# Out:
# <Axes: xlabel='cgpa', ylabel='placement_exam_marks'>

# %%
from sklearn.linear_model import Perceptron

# %%
pr = Perceptron()

# %%
pr.fit(x_scaled,y)
# Out:
# Perceptron()

# %%
# Weights of the perceptron of two columns W1,W2
pr.coef_
# Out:
# array([[ 1.36454492, -1.56893471]])

# %%
# Bias term of the perceptron 
pr.intercept_
# Out:
# array([0.])

# %%
# !pip install mlxtend

# %%
from mlxtend.plotting import plot_decision_regions

# %%
plot_decision_regions(x.values,y.values,clf = pr ,legend = 2)
# Out:
# <Axes: >

# %% [markdown]
# ## Support Vector Machine

# %%
clf = SVC(kernel="rbf", gamma=0.5, C=1.0)
clf.fit(x_scaled, y)
plt.figure(figsize=(10, 6))
plot_decision_regions(X=x_scaled, y=y.values, clf=clf, legend=2)
plt.xlabel("cgpa (Standardized)")
plt.ylabel("placement_exam_marks (Standardized)")
plt.title("Non-Linear SVM Decision Boundary")
plt.show()
